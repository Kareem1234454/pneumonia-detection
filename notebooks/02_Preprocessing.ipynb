# %% [markdown]
# #  Notebook 02 — Image Preprocessing & Enhancement (DIP)
# **Covers:** CLAHE, Histogram Equalization, Median Filter, Gaussian Filter

# %%
import sys; sys.path.append('..')
from src.preprocessing import *
import matplotlib.pyplot as plt
import os

TRAIN_DIR = '../data/raw/train'
normal_path    = os.path.join(TRAIN_DIR, 'NORMAL',    os.listdir(TRAIN_DIR+'/NORMAL')[30])
pneumonia_path = os.path.join(TRAIN_DIR, 'PNEUMONIA', os.listdir(TRAIN_DIR+'/PNEUMONIA')[30])
print('Sample paths ready ')
# Out:
# Sample paths ready

# %%
# Full preprocessing pipeline visualization
for path, label in [(normal_path, 'NORMAL'), (pneumonia_path, 'PNEUMONIA')]:
    print(label)
    visualize_preprocessing_pipeline(path, save=True, filename=f"{label.lower()}_pipeline.png")
    
print(' Pipeline figures saved!')
# Out:
# NORMAL
# Saved: c:\Users\Dell\Desktop\Project_DIP\outputs\figures\normal_pipeline.png
# PNEUMONIA
# Saved: c:\Users\Dell\Desktop\Project_DIP\outputs\figures\pneumonia_pipeline.png
#  Pipeline figures saved!
