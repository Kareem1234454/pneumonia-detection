# %% [markdown]
# #  Notebook 03 — Lung Segmentation (CV)
# **Covers:** Otsu Thresholding, Morphological Operations, Contour Detection

# %%
import sys; sys.path.append('..')
from src.preprocessing import preprocess_image
from src.segmentation  import *
import os

TRAIN_DIR = '../data/raw/train'
normal_path    = os.path.join(TRAIN_DIR, 'NORMAL',    os.listdir(TRAIN_DIR+'/NORMAL')[0])
pneumonia_path = os.path.join(TRAIN_DIR, 'PNEUMONIA', os.listdir(TRAIN_DIR+'/PNEUMONIA')[0])

normal_img,    _ = preprocess_image(normal_path)
pneumonia_img, _ = preprocess_image(pneumonia_path)
print('Images preprocessed ')
# Out:
# Images preprocessed

# %%
plot_segmentation_pipeline(normal_path,save=True)
plot_segmentation_pipeline(pneumonia_path,save=True)
# Out:
#  Saved  : c:\Users\Dell\Desktop\Project_DIP\outputs\figures\segmentation_pipeline.png
#  Saved  : c:\Users\Dell\Desktop\Project_DIP\outputs\figures\segmentation_pipeline.png

# %%
# Side-by-side comparison
compare_segmentation(normal_img, pneumonia_img, save=True)
print(' All segmentation figures saved!')
# Out:
#  Saved: c:\Users\Dell\Desktop\Project_DIP\outputs\figures\segmentation_comparison.png
#  All segmentation figures saved!
